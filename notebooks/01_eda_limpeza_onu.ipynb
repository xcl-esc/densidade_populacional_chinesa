# %%
import numpy as np
import pandas as pd

# %%
df_onu = pd.read_excel("../data/raw/onu_populacao_idade_sexo.xlsx", skiprows=15)

df_onu.head()
# Out:
#   Unnamed: 0 Unnamed: 1                            Unnamed: 2 Unnamed: 3  \
# 0      Index    Variant  Region, subregion, country or area *      Notes
# 1          1  Estimates                                 World        NaN
# 2          2  Estimates                                 World        NaN
# 3          3  Estimates                                 World        NaN
# 4          4  Estimates                                 World        NaN
#
#       Unnamed: 4       Unnamed: 5       Unnamed: 6   Unnamed: 7 Unnamed: 8  \
# 0  Location code  ISO3 Alpha-code  ISO2 Alpha-code  SDMX code**       Type
# 1            900              NaN              NaN            1      World
# 2            900              NaN              NaN            1      World
# 3            900              NaN              NaN            1      World
# 4            900              NaN              NaN            1      World
#
#     Unnamed: 9  ... Unnamed: 102 Unnamed: 103 Unnamed: 104 Unnamed: 105  \
# ...

# %%
df_onu.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21984 entries, 0 to 21983
# Columns: 112 entries, Unnamed: 0 to Unnamed: 111
# dtypes: object(107), str(5)
# memory usage: 18.8+ MB

# %%
df_onu.describe()
# Out:
#        Unnamed: 0 Unnamed: 1                       Unnamed: 2  Unnamed: 3  \
# count       21984      21984                            21984        5555
# unique      21984          2                              301          47
# top         Index  Estimates  Latin America and the Caribbean           2
# freq            1      21983                              148         814
#
#         Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7    Unnamed: 8  \
# count        21984      17539      17465       20943         21984
# unique         303        238        237         282            10
# top            900        BDI         BI         419  Country/Area
# freq            74         74         74         148         17538
#
#         Unnamed: 9  ...  Unnamed: 102  Unnamed: 103  Unnamed: 104  \
# count        21984  ...         21984         21984         21984
# unique          38  ...          9992          9341          8593
# ...

# %%
coluna_10 = df_onu.iloc[:, 10]
print(coluna_10)
# Out:
# 0        Year
# 1        1950
# 2        1951
# 3        1952
# 4        1953
#          ...
# 21979    2019
# 21980    2020
# 21981    2021
# 21982    2022
# 21983    2023
# Name: Unnamed: 10, Length: 21984, dtype: object

# %%
coluna_11 = df_onu.iloc[:, 11]
print(coluna_11)
# Out:
# 0                 0
# 1        81507.1885
# 2         83568.469
# 3         86252.372
# 4        88590.8955
#             ...
# 21979        0.1325
# 21980         0.126
# 21981        0.1055
# 21982         0.099
# 21983         0.096
# Name: Total population by single age, both sexes combined (thousands), Length: 21984, dtype: object
